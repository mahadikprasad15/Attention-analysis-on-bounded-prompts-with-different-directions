# %% [markdown]
# <a href="https://colab.research.google.com/github/mahadikprasad15/Attention-analysis-on-bounded-prompts-with-different-directions/blob/main/Attention_study_for_universal_suffixes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from huggingface_hub import login
login()

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/mahadikprasad15/Attention-analysis-on-bounded-prompts-with-different-directions.git
# %cd Attention-analysis-on-bounded-prompts-with-different-directions/

# %%
# !git fetch
# !git status

# %%
# !git pull

# %%
# !pip install -r requirements.txt
# !pip install --upgrade transformers accelerate bitsandbytes

# %%
# !python main.py \
    --model_name "meta-llama/Llama-3.2-1B-Instruct" \
    --step train \
    --n_samples 200 \
    --use_llm_labeling \
    --cerebras_api_key "csk-mhfprn3kttt2vp34ct22936v8cef4km5ewhnwc3tkptmk6eh"

# %%
# !python main.py \
    --model_name "meta-llama/Llama-3.2-1B-Instruct" \
    --step evaluate \
    --save_dir "experiments/colab_run" \
    --n_samples 200

# %%
# !python src/experiments/optimize_suffix.py \
    --model_name "meta-llama/Llama-3.2-1B-Instruct" \
    --n_samples 10 \
    --use_llm_labeling \
    --cerebras_api_key "csk-mhfprn3kttt2vp34ct22936v8cef4km5ewhnwc3tkptmk6eh"

# %%
# !python main.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --step all \
    --n_samples 50 \
    --use_llm_labeling \
    --cerebras_api_key "csk-mhfprn3kttt2vp34ct22936v8cef4km5ewhnwc3tkptmk6eh"
